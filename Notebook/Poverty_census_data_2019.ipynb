# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
poverty_df = pd.read_csv('../data/Census_poverty_data_2019.csv')

# %%
testing = poverty_df.T.reset_index()

# %%
testing.head()
# Out:
#                                            index  \
# 0                                          Label
# 1                       Alabama!!Total!!Estimate
# 2                Alabama!!Total!!Margin of Error
# 3         Alabama!!Below poverty level!!Estimate
# 4  Alabama!!Below poverty level!!Margin of Error
#
#                                                   0        1  \
# 0  Population for whom poverty status is determined      AGE
# 1                                         4,781,688      NaN
# 2                                            ±3,063      NaN
# 3                                           739,108      NaN
# 4                                           ±24,870      NaN
#
#                         2                          3  \
# 0          Under 18 years              Under 5 years
# 1               1,068,804                    281,201
# 2                  ±4,435                     ±4,432
# 3                 228,412                     67,723
# ...

# %%
testing.columns = testing.loc[0]

# %%
testing.head()
# Out:
# 0                                          Label  \
# 0                                          Label
# 1                       Alabama!!Total!!Estimate
# 2                Alabama!!Total!!Margin of Error
# 3         Alabama!!Below poverty level!!Estimate
# 4  Alabama!!Below poverty level!!Margin of Error
#
# 0  Population for whom poverty status is determined      AGE  \
# 0  Population for whom poverty status is determined      AGE
# 1                                         4,781,688      NaN
# 2                                            ±3,063      NaN
# 3                                           739,108      NaN
# 4                                           ±24,870      NaN
#
# 0          Under 18 years              Under 5 years  \
# 0          Under 18 years              Under 5 years
# 1               1,068,804                    281,201
# 2                  ±4,435                     ±4,432
# 3                 228,412                     67,723
# ...

# %%
testing.shape
# Out:
# (312, 71)

# %%
testing = testing.drop(0)

# %%
testing.head()
# Out:
# 0                                           Label  \
# 1                        Alabama!!Total!!Estimate
# 2                 Alabama!!Total!!Margin of Error
# 3          Alabama!!Below poverty level!!Estimate
# 4   Alabama!!Below poverty level!!Margin of Error
# 5  Alabama!!Percent below poverty level!!Estimate
#
# 0 Population for whom poverty status is determined     AGE  \
# 1                                        4,781,688     NaN
# 2                                           ±3,063     NaN
# 3                                          739,108     NaN
# 4                                          ±24,870     NaN
# 5                                           15.50%     NaN
#
# 0         Under 18 years             Under 5 years             5 to 17 years  \
# 1              1,068,804                   281,201                   787,603
# 2                 ±4,435                    ±4,432                    ±5,534
# ...

# %%
for c in testing.columns:
    print(c)
# Out:
# Population for whom poverty status is determined
#     AGE
#         Under 18 years
#             Under 5 years
#             5 to 17 years
#             Related children of householder under 18 years
#         18 to 64 years
#             18 to 34 years
#             35 to 64 years
#         60 years and over
#         65 years and over
#     SEX
#         Male
#         Female
#     RACE AND HISPANIC OR LATINO ORIGIN
#         White alone
#         Black or African American alone
#         American Indian and Alaska Native alone
#         Asian alone
#         Native Hawaiian and Other Pacific Islander alone
#         Some other race alone
#         Two or more races
#         Hispanic or Latino origin (of any race)
#         White alone, not Hispanic or Latino
#     EDUCATIONAL ATTAINMENT
#         Population 25 years and over
#             Less than high school graduate
#             High school graduate (includes equivalency)
#             Some college, associate's degree
# ...

# %%
testing[['Region', 'Value', 'Notation']] = testing['Label'].str.split('!!', expand = True)

# %%
testing.head()
# Out:
# 0                                           Label  \
# 1                        Alabama!!Total!!Estimate
# 2                 Alabama!!Total!!Margin of Error
# 3          Alabama!!Below poverty level!!Estimate
# 4   Alabama!!Below poverty level!!Margin of Error
# 5  Alabama!!Percent below poverty level!!Estimate
#
# 0 Population for whom poverty status is determined     AGE  \
# 1                                        4,781,688     NaN
# 2                                           ±3,063     NaN
# 3                                          739,108     NaN
# 4                                          ±24,870     NaN
# 5                                           15.50%     NaN
#
# 0         Under 18 years             Under 5 years             5 to 17 years  \
# 1              1,068,804                   281,201                   787,603
# 2                 ±4,435                    ±4,432                    ±5,534
# ...

# %%
testing = testing.drop('Label', axis = 1)
testing.head()
# Out:
# 0 Population for whom poverty status is determined     AGE  \
# 1                                        4,781,688     NaN
# 2                                           ±3,063     NaN
# 3                                          739,108     NaN
# 4                                          ±24,870     NaN
# 5                                           15.50%     NaN
#
# 0         Under 18 years             Under 5 years             5 to 17 years  \
# 1              1,068,804                   281,201                   787,603
# 2                 ±4,435                    ±4,432                    ±5,534
# 3                228,412                    67,723                   160,689
# 4                ±11,511                    ±5,010                    ±8,920
# 5                 21.40%                    24.10%                    20.40%
#
# 0             Related children of householder under 18 years  \
# 1                                          1,064,947
# ...

# %%
testing.shape
# Out:
# (312, 71)

# %%
testing.Value.value_counts()
# Out:
# Below poverty level            104
# Percent below poverty level    104
# Total                          104
# Name: Value, dtype: int64

# %%
testing.columns
# Out:
# Index(['Population for whom poverty status is determined', '    AGE',
#        '        Under 18 years', '            Under 5 years',
#        '            5 to 17 years',
#        '            Related children of householder under 18 years',
#        '        18 to 64 years', '            18 to 34 years',
#        '            35 to 64 years', '        60 years and over',
#        '        65 years and over', '    SEX', '        Male',
#        '        Female', '    RACE AND HISPANIC OR LATINO ORIGIN',
#        '        White alone', '        Black or African American alone',
#        '        American Indian and Alaska Native alone',
#        '        Asian alone',
#        '        Native Hawaiian and Other Pacific Islander alone',
#        '        Some other race alone', '        Two or more races',
#        '        Hispanic or Latino origin (of any race)',
#        '        White alone, not Hispanic or Latino',
# ...

# %%
for c in testing.columns: 
    print(c)
# Out:
# Population for whom poverty status is determined
#     AGE
#         Under 18 years
#             Under 5 years
#             5 to 17 years
#             Related children of householder under 18 years
#         18 to 64 years
#             18 to 34 years
#             35 to 64 years
#         60 years and over
#         65 years and over
#     SEX
#         Male
#         Female
#     RACE AND HISPANIC OR LATINO ORIGIN
#         White alone
#         Black or African American alone
#         American Indian and Alaska Native alone
#         Asian alone
#         Native Hawaiian and Other Pacific Islander alone
#         Some other race alone
#         Two or more races
#         Hispanic or Latino origin (of any race)
#         White alone, not Hispanic or Latino
#     EDUCATIONAL ATTAINMENT
#         Population 25 years and over
#             Less than high school graduate
#             High school graduate (includes equivalency)
#             Some college, associate's degree
# ...

# %%
columns_list = testing.columns

# %%
total = []
below_poverty_level = []
percent_below_poverty_level = []

for ind, row in testing.iterrows(): 
    if row ['Value'] == 'Percent below poverty level':
        percent_below_poverty_level.append(row)
    elif row ['Value'] == 'Below poverty level':
        below_poverty_level.append(row)
    else: total.append(row.to_frame())

# %%
testing.head()
# Out:
# 0 Population for whom poverty status is determined     AGE  \
# 1                                        4,781,688     NaN
# 2                                           ±3,063     NaN
# 3                                          739,108     NaN
# 4                                          ±24,870     NaN
# 5                                           15.50%     NaN
#
# 0         Under 18 years             Under 5 years             5 to 17 years  \
# 1              1,068,804                   281,201                   787,603
# 2                 ±4,435                    ±4,432                    ±5,534
# 3                228,412                    67,723                   160,689
# 4                ±11,511                    ±5,010                    ±8,920
# 5                 21.40%                    24.10%                    20.40%
#
# 0             Related children of householder under 18 years  \
# 1                                          1,064,947
# ...

# %%
pd.concat(total, axis = 1).T
# Out:
# 0   Population for whom poverty status is determined     AGE  \
# 1                                          4,781,688     NaN
# 2                                             ±3,063     NaN
# 7                                            713,725     NaN
# 8                                             ±1,271     NaN
# 13                                         7,116,266     NaN
# ..                                               ...     ...
# 296                                           ±3,164     NaN
# 301                                          563,528     NaN
# 302                                           ±1,747     NaN
# 307                                        3,167,190     NaN
# 308                                             ±936     NaN
#
# 0           Under 18 years             Under 5 years  \
# 1                1,068,804                   281,201
# 2                   ±4,435                    ±4,432
# 7                  175,678                    49,694
# ...

# %%
total_df = testing[testing['Value'].isin(['Total'])]
total_df
# Out:
# 0   Population for whom poverty status is determined     AGE  \
# 1                                          4,781,688     NaN
# 2                                             ±3,063     NaN
# 7                                            713,725     NaN
# 8                                             ±1,271     NaN
# 13                                         7,116,266     NaN
# ..                                               ...     ...
# 296                                           ±3,164     NaN
# 301                                          563,528     NaN
# 302                                           ±1,747     NaN
# 307                                        3,167,190     NaN
# 308                                             ±936     NaN
#
# 0           Under 18 years             Under 5 years  \
# 1                1,068,804                   281,201
# 2                   ±4,435                    ±4,432
# 7                  175,678                    49,694
# ...

# %%
percent_below_poverty_level_df = testing[testing['Value'].isin(['Percent below poverty level'])]
percent_below_poverty_level_df
# Out:
# 0   Population for whom poverty status is determined     AGE  \
# 5                                             15.50%     NaN
# 6                                               ±0.5     NaN
# 11                                            10.10%     NaN
# 12                                              ±1.1     NaN
# 17                                            13.50%     NaN
# ..                                               ...     ...
# 300                                             ±0.3     NaN
# 305                                           10.10%     NaN
# 306                                             ±1.0     NaN
# 311                                           43.50%     NaN
# 312                                             ±0.8     NaN
#
# 0           Under 18 years             Under 5 years  \
# 5                   21.40%                    24.10%
# 6                     ±1.1                      ±1.8
# 11                  13.00%                    17.20%
# ...

# %%
below_poverty_level_df  = testing[testing['Value'].isin(['Below poverty level'])]
below_poverty_level_df
# Out:
# 0   Population for whom poverty status is determined     AGE  \
# 3                                            739,108     NaN
# 4                                            ±24,870     NaN
# 9                                             71,938     NaN
# 10                                            ±7,880     NaN
# 15                                           958,442     NaN
# ..                                               ...     ...
# 298                                          ±18,294     NaN
# 303                                           56,945     NaN
# 304                                           ±5,626     NaN
# 309                                        1,376,809     NaN
# 310                                          ±24,017     NaN
#
# 0           Under 18 years             Under 5 years  \
# 3                  228,412                    67,723
# 4                  ±11,511                    ±5,010
# 9                   22,921                     8,547
# ...

# %%
first_column = total_df.pop('Region')
total_df.insert(0, 'Region', first_column)
second_column = total_df.pop('Value')
total_df.insert(1, 'Value', second_column)
total_df
# Out:
# 0         Region  Value Population for whom poverty status is determined  \
# 1        Alabama  Total                                        4,781,688
# 2        Alabama  Total                                           ±3,063
# 7         Alaska  Total                                          713,725
# 8         Alaska  Total                                           ±1,271
# 13       Arizona  Total                                        7,116,266
# ..           ...    ...                                              ...
# 296    Wisconsin  Total                                           ±3,164
# 301      Wyoming  Total                                          563,528
# 302      Wyoming  Total                                           ±1,747
# 307  Puerto Rico  Total                                        3,167,190
# 308  Puerto Rico  Total                                             ±936
#
# 0       AGE         Under 18 years             Under 5 years  \
# ...

# %%
first_column = percent_below_poverty_level_df.pop('Region')
percent_below_poverty_level_df.insert(0, 'Region', first_column)
second_column = percent_below_poverty_level_df.pop('Value')
percent_below_poverty_level_df.insert(1, 'Value', second_column)
percent_below_poverty_level_df
# Out:
# 0         Region                        Value  \
# 5        Alabama  Percent below poverty level
# 6        Alabama  Percent below poverty level
# 11        Alaska  Percent below poverty level
# 12        Alaska  Percent below poverty level
# 17       Arizona  Percent below poverty level
# ..           ...                          ...
# 300    Wisconsin  Percent below poverty level
# 305      Wyoming  Percent below poverty level
# 306      Wyoming  Percent below poverty level
# 311  Puerto Rico  Percent below poverty level
# 312  Puerto Rico  Percent below poverty level
#
# 0   Population for whom poverty status is determined     AGE  \
# 5                                             15.50%     NaN
# 6                                               ±0.5     NaN
# 11                                            10.10%     NaN
# 12                                              ±1.1     NaN
# 17                                            13.50%     NaN
# ...

# %%
first_column = below_poverty_level_df.pop('Region')
below_poverty_level_df.insert(0, 'Region', first_column)
second_column = below_poverty_level_df.pop('Value')
below_poverty_level_df.insert(1, 'Value', second_column)
below_poverty_level_df
# Out:
# 0         Region                Value  \
# 3        Alabama  Below poverty level
# 4        Alabama  Below poverty level
# 9         Alaska  Below poverty level
# 10        Alaska  Below poverty level
# 15       Arizona  Below poverty level
# ..           ...                  ...
# 298    Wisconsin  Below poverty level
# 303      Wyoming  Below poverty level
# 304      Wyoming  Below poverty level
# 309  Puerto Rico  Below poverty level
# 310  Puerto Rico  Below poverty level
#
# 0   Population for whom poverty status is determined     AGE  \
# 3                                            739,108     NaN
# 4                                            ±24,870     NaN
# 9                                             71,938     NaN
# 10                                            ±7,880     NaN
# 15                                           958,442     NaN
# ..                                               ...     ...
# 298                                          ±18,294     NaN
# ...

# %%
below_poverty_level_df.to_csv(r'../cleaned_python_csv/below_poverty_level.csv')
percent_below_poverty_level_df.to_csv(r'../cleaned_python_csv/percent_below_poverty_level.csv')
total_df.to_csv(r'../cleaned_python_csv/total_df.csv')
