# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
obesity_df = pd.read_csv('../data/Behavioral_Risk_Factor_Surveillance_System__BRFSS__Prevalence_Data__2011_to_present_.csv')

# %%
obesity_df.head()
# Out:
#    Year Locationabbr Locationdesc          Class           Topic  \
# 0  2012           GU         Guam   Demographics             Age
# 1  2012           GU         Guam   Demographics             Age
# 2  2013           GU         Guam  Health Status  Overall Health
# 3  2013           GU         Guam   Demographics  Marital Status
# 4  2013           PR  Puerto Rico   Demographics             Age
#
#                        Question     Response       Break_Out  \
# 0             What is your age?  55-64 years         Overall
# 1             What is your age?  35-44 years          Female
# 2   How is your general health?    Excellent           18-24
# 3  What is your marital status?    Partnered  H.S. or G.E.D.
# 4             What is your age?  25-34 years  Some post-H.S.
#
#    Break_Out_Category  Sample_Size  ...  Data_Value_Footnote  DataSource  \
# 0             Overall          296  ...                  NaN       BRFSS
# ...

# %%
obesity_df.columns
# Out:
# Index(['Year', 'Locationabbr', 'Locationdesc', 'Class', 'Topic', 'Question',
#        'Response', 'Break_Out', 'Break_Out_Category', 'Sample_Size',
#        'Data_value', 'Confidence_limit_Low', 'Confidence_limit_High',
#        'Display_order', 'Data_value_unit', 'Data_value_type',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 'DataSource',
#        'ClassId', 'TopicId', 'LocationID', 'BreakoutID', 'BreakOutCategoryID',
#        'QuestionID', 'ResponseID', 'GeoLocation'],
#       dtype='object')

# %%
obesity_df_2019.shape
# Out:
# (47074, 27)

# %%
race_ethinicity_df  = obesity_df[obesity_df['Break_Out_Category'].isin(['Race/Ethnicity'])]

# %%
age_df = obesity_df[obesity_df['Break_Out_Category'].isin(['Age Group'])]
age_df
# Out:
#          Year Locationabbr Locationdesc                        Class  \
# 2        2013           GU         Guam                Health Status
# 6        2011           GU         Guam                 Demographics
# 7        2019           KS       Kansas  Health Care Access/Coverage
# 9        2013           GU         Guam                 Immunization
# 10       2011           GU         Guam    Chronic Health Indicators
# ...       ...          ...          ...                          ...
# 1827468  2018           WI    Wisconsin                Health Status
# 1827469  2018           GU         Guam                       Injury
# 1827470  2018           WY      Wyoming                 Immunization
# 1827481  2018           GU         Guam                     HIV-AIDS
# 1827489  2018           GU         Guam                 Demographics
#
#                    Topic                                           Question  \
# ...

# %%
income_df = obesity_df[obesity_df['Break_Out_Category'].isin(['Household Income'])]
income_df
# Out:
#          Year Locationabbr Locationdesc                      Class  \
# 11       2011           GU         Guam               Demographics
# 39       2019           KY     Kentucky               Demographics
# 53       2019           LA    Louisiana  Chronic Health Indicators
# 72       2011           GU         Guam               Demographics
# 74       2019           AL      Alabama               Demographics
# ...       ...          ...          ...                        ...
# 1827482  2018           PR  Puerto Rico  Chronic Health Indicators
# 1827484  2018           WY      Wyoming          Physical Activity
# 1827485  2018           PR  Puerto Rico                Tobacco Use
# 1827490  2018           WY      Wyoming               Demographics
# 1827491  2018           GU         Guam  Chronic Health Indicators
#
#                      Topic                                           Question  \
# 11                     Age                                  What is your age?
# ...

# %%
education_df = obesity_df[obesity_df['Break_Out_Category'].isin(['Education Attained'])]
education_df
# Out:
#          Year Locationabbr Locationdesc                      Class  \
# 3        2013           GU         Guam               Demographics
# 4        2013           PR  Puerto Rico               Demographics
# 12       2013           GU         Guam              Health Status
# 20       2019           KY     Kentucky  Chronic Health Indicators
# 22       2019           KY     Kentucky  Chronic Health Indicators
# ...       ...          ...          ...                        ...
# 1827459  2018           WY      Wyoming               Demographics
# 1827460  2018           PR  Puerto Rico               Demographics
# 1827478  2018           PR  Puerto Rico                     Injury
# 1827479  2018           WY      Wyoming  Chronic Health Indicators
# 1827488  2018           GU         Guam               Demographics
#
#                           Topic  \
# 3                Marital Status
# 4                           Age
# 12               Overall Health
# ...

# %%
gender_df =obesity_df[obesity_df['Break_Out_Category'].isin(['Gender'])]
gender_df
# Out:
#          Year Locationabbr  Locationdesc                         Class  \
# 1        2012           GU          Guam                  Demographics
# 15       2013           GA       Georgia                  Demographics
# 16       2019           KS        Kansas                   Tobacco Use
# 19       2011           ND  North Dakota     Chronic Health Indicators
# 21       2019           KY      Kentucky     Chronic Health Indicators
# ...       ...          ...           ...                           ...
# 1827409  2018           WI     Wisconsin  Overweight and Obesity (BMI)
# 1827433  2018           PR   Puerto Rico                  Demographics
# 1827437  2018           GU          Guam                        Injury
# 1827453  2018           PR   Puerto Rico                 Health Status
# 1827473  2018           GU          Guam                  Demographics
#
#                           Topic  \
# 1                           Age
# 15                         Race
# ...

# %%
overall_df = obesity_df[obesity_df['Break_Out_Category'].isin(['Overall'])]
overall_df
# Out:
#          Year Locationabbr                   Locationdesc  \
# 0        2012           GU                           Guam
# 8        2013           GU                           Guam
# 26       2019           KY                       Kentucky
# 46       2019           KY                       Kentucky
# 47       2019           KY                       Kentucky
# ...       ...          ...                            ...
# 1827414  2018           WY                        Wyoming
# 1827421  2018           WI                      Wisconsin
# 1827422  2018           UW  All States and DC (median) **
# 1827463  2018           WI                      Wisconsin
# 1827471  2018           UW  All States and DC (median) **
#
#                                 Class                   Topic  \
# 0                        Demographics                     Age
# 8                        Demographics                     Age
# 26          Chronic Health Indicators             Skin Cancer
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-21b39a0c47ff> in <module>
# ----> 1 overall_df['Response'] =='Overweight (BMI 25.0-29.9)'.value_counts()
#
# AttributeError: 'str' object has no attribute 'value_counts'
