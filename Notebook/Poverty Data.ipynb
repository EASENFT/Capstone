# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
poverty_df = pd.read_csv('../data/poverty data 2019.csv')
poverty_df.head()
# Out:
#        geoid           name  B17001001  B17001001, Error  B17001002  \
# 0    01000US  United States  320118791             24954   39490096
# 1  04000US01        Alabama    4781688              3063     739108
# 2  04000US02         Alaska     713725              1271      71938
# 3  04000US04        Arizona    7116266              3597     958442
# 4  04000US05       Arkansas    2929117              2439     474739
#
#    B17001002, Error  B17001003  B17001003, Error  B17001004  B17001004, Error  \
# 0            242000   17473451            123014    1755965             33740
# 1             24870     319539             13494      36482              3005
# 2              7880      33577              3994       4049              1033
# 3             33279     439568             19002      45532              4367
# 4             16707     204965              9064      21588              3158
#
#    ...  B17001055  B17001055, Error  B17001056  B17001056, Error  B17001057  \
# ...

# %%
poverty_df.shape
# Out:
# (52, 120)
