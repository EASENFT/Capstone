# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### read in poverty csv

# %%
poverty_rates_19 = pd.read_csv('../Data/est19us.csv')
poverty_rates_16 = pd.read_csv('../Data/est16us.csv')
poverty_rates_13 = pd.read_csv('../Data/est13us.csv')

# %%
poverty_rates_19.head()
# Out:
#    State FIPS Code Postal Code           Name Poverty Estimate, All Ages  \
# 0                0          US  United States                 39,490,096
# 1                1          AL        Alabama                    747,478
# 2                2          AK         Alaska                     73,033
# 3                4          AZ        Arizona                    963,007
# 4                5          AR       Arkansas                    468,575
#
#   90% CI Lower Bound 90% CI Upper Bound  Poverty Percent, All Ages  \
# 0         39,248,096         39,732,096                       12.3
# 1            730,491            764,465                       15.6
# 2             68,640             77,426                       10.2
# 3            940,142            985,872                       13.5
# 4            456,478            480,672                       16.0
#
#    90% CI Lower Bound.1  90% CI Upper Bound.1 Poverty Estimate, Age 0-17  ...  \
# ...

# %%
poverty_rates_19.Name.value_counts()
# Out:
# Wisconsin               1
# Virginia                1
# New Jersey              1
# Kansas                  1
# Arizona                 1
# Montana                 1
# Massachusetts           1
# Indiana                 1
# Missouri                1
# Tennessee               1
# New Mexico              1
# Colorado                1
# Rhode Island            1
# Georgia                 1
# Delaware                1
# Oregon                  1
# Connecticut             1
# Iowa                    1
# Idaho                   1
# South Carolina          1
# North Carolina          1
# Washington              1
# Kentucky                1
# Arkansas                1
# Alaska                  1
# United States           1
# Nevada                  1
# New Hampshire           1
# Ohio                    1
# Alabama                 1
# Maryland                1
# South Dakota            1
# New York                1
# West Virginia           1
# Pennsylvania            1
# ...

# %%
poverty_rates_16.head()
# Out:
#    State FIPS Code Postal Code           Name Poverty Estimate, All Ages  \
# 0                0          US  United States                 44,268,996
# 1                1          AL        Alabama                    814,197
# 2                2          AK         Alaska                     71,916
# 3                4          AZ        Arizona                  1,107,153
# 4                5          AR       Arkansas                    497,388
#
#   90% CI Lower Bound 90% CI Upper Bound  Poverty Percent, All Ages  \
# 0         44,022,086         44,515,906                       14.0
# 1            796,927            831,467                       17.2
# 2             67,813             76,019                        9.9
# 3          1,086,482          1,127,824                       16.4
# 4            485,180            509,596                       17.2
#
#    90% CI Lower Bound.1  90% CI Upper Bound.1 Poverty Estimate, Age 0-17  ...  \
# ...

# %%
poverty_rates_13.head()
# Out:
#    State FIPS Code Postal Code           Name Poverty Estimate, All Ages  \
# 0                0          US  United States                 48,810,868
# 1                1          AL        Alabama                    889,091
# 2                2          AK         Alaska                     72,643
# 3                4          AZ        Arizona                  1,206,948
# 4                5          AR       Arkansas                    557,399
#
#   90% CI Lower Bound 90% CI Upper Bound  Poverty Percent, All Ages  \
# 0         48,554,692         49,067,044                       15.8
# 1            873,141            905,041                       18.9
# 2             69,056             76,230                       10.1
# 3          1,184,107          1,229,789                       18.6
# 4            545,273            569,525                       19.4
#
#    90% CI Lower Bound.1  90% CI Upper Bound.1 Poverty Estimate, Age 0-17  ...  \
# ...

# %% [markdown]
# ### clean up data: drop unnecessary columns

# %%
poverty_rates_13.columns
# Out:
# Index(['State FIPS Code', 'Postal Code', 'Name', 'Poverty Estimate, All Ages',
#        '90% CI Lower Bound', '90% CI Upper Bound', 'Poverty Percent, All Ages',
#        '90% CI Lower Bound.1', '90% CI Upper Bound.1',
#        'Poverty Estimate, Age 0-17', '90% CI Lower Bound.2',
#        '90% CI Upper Bound.2', 'Poverty Percent, Age 0-17',
#        '90% CI Lower Bound.3', '90% CI Upper Bound.3',
#        'Poverty Estimate, Age 5-17 in Families', '90% CI Lower Bound.4',
#        '90% CI Upper Bound.4', 'Poverty Percent, Age 5-17 in Families',
#        '90% CI Lower Bound.5', '90% CI Upper Bound.5',
#        'Median Household Income', '90% CI Lower Bound.6',
#        '90% CI Upper Bound.6', 'Poverty Estimate, Age 0-4',
#        '90% CI Lower Bound.7', '90% CI Upper Bound.7',
#        'Poverty Percent, Age 0-4', '90% CI Lower Bound.8',
#        '90% CI Upper Bound.8'],
#       dtype='object')

# %%
clean_pr_19 = poverty_rates_19.drop(columns =['State FIPS Code','Poverty Estimate, Age 0-17', '90% CI Lower Bound.2',
       '90% CI Upper Bound.2', 'Poverty Percent, Age 0-17',
       '90% CI Lower Bound.3', '90% CI Upper Bound.3',
       'Poverty Estimate, Age 5-17 in Families', '90% CI Lower Bound.4',
       '90% CI Upper Bound.4', 'Poverty Percent, Age 5-17 in Families',
       '90% CI Lower Bound.5', '90% CI Upper Bound.5','Poverty Estimate, Age 0-4',
       '90% CI Lower Bound.7', '90% CI Upper Bound.7',
       'Poverty Percent, Age 0-4', '90% CI Lower Bound.8',
       '90% CI Upper Bound.8'])
clean_pr_19.head()
# Out:
#   Postal Code           Name Poverty Estimate, All Ages 90% CI Lower Bound  \
# 0          US  United States                 39,490,096         39,248,096
# 1          AL        Alabama                    747,478            730,491
# 2          AK         Alaska                     73,033             68,640
# 3          AZ        Arizona                    963,007            940,142
# 4          AR       Arkansas                    468,575            456,478
#
#   90% CI Upper Bound  Poverty Percent, All Ages  90% CI Lower Bound.1  \
# 0         39,732,096                       12.3                  12.2
# 1            764,465                       15.6                  15.2
# 2             77,426                       10.2                   9.6
# 3            985,872                       13.5                  13.2
# 4            480,672                       16.0                  15.6
#
#    90% CI Upper Bound.1 Median Household Income 90% CI Lower Bound.6  \
# ...

# %%
clean_pr_16 = poverty_rates_16.drop(columns =['State FIPS Code','Poverty Estimate, Age 0-17', '90% CI Lower Bound.2',
       '90% CI Upper Bound.2', 'Poverty Percent, Age 0-17',
       '90% CI Lower Bound.3', '90% CI Upper Bound.3',
       'Poverty Estimate, Age 5-17 in Families', '90% CI Lower Bound.4',
       '90% CI Upper Bound.4', 'Poverty Percent, Age 5-17 in Families',
       '90% CI Lower Bound.5', '90% CI Upper Bound.5','Poverty Estimate, Age 0-4',
       '90% CI Lower Bound.7', '90% CI Upper Bound.7',
       'Poverty Percent, Age 0-4', '90% CI Lower Bound.8',
       '90% CI Upper Bound.8'])
clean_pr_16.head()
# Out:
#   Postal Code           Name Poverty Estimate, All Ages 90% CI Lower Bound  \
# 0          US  United States                 44,268,996         44,022,086
# 1          AL        Alabama                    814,197            796,927
# 2          AK         Alaska                     71,916             67,813
# 3          AZ        Arizona                  1,107,153          1,086,482
# 4          AR       Arkansas                    497,388            485,180
#
#   90% CI Upper Bound  Poverty Percent, All Ages  90% CI Lower Bound.1  \
# 0         44,515,906                       14.0                  13.9
# 1            831,467                       17.2                  16.8
# 2             76,019                        9.9                   9.3
# 3          1,127,824                       16.4                  16.1
# 4            509,596                       17.2                  16.8
#
#    90% CI Upper Bound.1 Median Household Income 90% CI Lower Bound.6  \
# ...

# %%
clean_pr_13 = poverty_rates_13.drop(columns =['State FIPS Code','Poverty Estimate, Age 0-17', '90% CI Lower Bound.2',
       '90% CI Upper Bound.2', 'Poverty Percent, Age 0-17',
       '90% CI Lower Bound.3', '90% CI Upper Bound.3',
       'Poverty Estimate, Age 5-17 in Families', '90% CI Lower Bound.4',
       '90% CI Upper Bound.4', 'Poverty Percent, Age 5-17 in Families',
       '90% CI Lower Bound.5', '90% CI Upper Bound.5','Poverty Estimate, Age 0-4',
       '90% CI Lower Bound.7', '90% CI Upper Bound.7',
       'Poverty Percent, Age 0-4', '90% CI Lower Bound.8',
       '90% CI Upper Bound.8'])
clean_pr_13.head()
# Out:
#   Postal Code           Name Poverty Estimate, All Ages 90% CI Lower Bound  \
# 0          US  United States                 48,810,868         48,554,692
# 1          AL        Alabama                    889,091            873,141
# 2          AK         Alaska                     72,643             69,056
# 3          AZ        Arizona                  1,206,948          1,184,107
# 4          AR       Arkansas                    557,399            545,273
#
#   90% CI Upper Bound  Poverty Percent, All Ages  90% CI Lower Bound.1  \
# 0         49,067,044                       15.8                  15.7
# 1            905,041                       18.9                  18.6
# 2             76,230                       10.1                   9.6
# 3          1,229,789                       18.6                  18.2
# 4            569,525                       19.4                  19.0
#
#    90% CI Upper Bound.1 Median Household Income 90% CI Lower Bound.6  \
# ...

# %%
clean_pr_13.rename(columns = {'Name':'Region'}, inplace = True)
clean_pr_16.rename(columns = {'Name':'Region'}, inplace = True)
clean_pr_19.rename(columns = {'Name':'Region'}, inplace = True)

# %%
clean_pr_13['Year'] = 2013
clean_pr_16['Year'] = 2016
clean_pr_19['Year'] = 2019

# %%
all_years = pd.concat([clean_pr_13, clean_pr_16, clean_pr_19])
all_years
# Out:
#    Postal Code         Region Poverty Estimate, All Ages 90% CI Lower Bound  \
# 0           US  United States                 48,810,868         48,554,692
# 1           AL        Alabama                    889,091            873,141
# 2           AK         Alaska                     72,643             69,056
# 3           AZ        Arizona                  1,206,948          1,184,107
# 4           AR       Arkansas                    557,399            545,273
# ..         ...            ...                        ...                ...
# 47          VA       Virginia                    822,944            805,003
# 48          WA     Washington                    731,216            712,292
# 49          WV  West Virginia                    281,175            271,926
# 50          WI      Wisconsin                    591,404            578,030
# 51          WY        Wyoming                     55,776             51,997
#
# ...

# %%
clean_pr_13
# Out:
#    Postal Code                Region Poverty Estimate, All Ages  \
# 0           US         United States                 48,810,868
# 1           AL               Alabama                    889,091
# 2           AK                Alaska                     72,643
# 3           AZ               Arizona                  1,206,948
# 4           AR              Arkansas                    557,399
# 5           CA            California                  6,328,064
# 6           CO              Colorado                    665,351
# 7           CT           Connecticut                    373,387
# 8           DE              Delaware                    115,774
# 9           DC  District of Columbia                    115,096
# 10          FL               Florida                  3,268,130
# 11          GA               Georgia                  1,849,944
# 12          HI                Hawaii                    153,375
# 13          ID                 Idaho                    246,708
# ...

# %%
clean_pr_19.to_csv(r'../cleaned_python_csv/clean_pr_19.csv')
clean_pr_16.to_csv(r'../cleaned_python_csv/clean_pr_16.csv')
clean_pr_13.to_csv(r'../cleaned_python_csv/clean_pr_13.csv')
all_years.to_csv(r'../cleaned_python_csv/all_year_pr.csv')

# %%
clean_pr_13
# Out:
#    Postal Code                Region Poverty Estimate, All Ages  \
# 0           US         United States                 48,810,868
# 1           AL               Alabama                    889,091
# 2           AK                Alaska                     72,643
# 3           AZ               Arizona                  1,206,948
# 4           AR              Arkansas                    557,399
# 5           CA            California                  6,328,064
# 6           CO              Colorado                    665,351
# 7           CT           Connecticut                    373,387
# 8           DE              Delaware                    115,774
# 9           DC  District of Columbia                    115,096
# 10          FL               Florida                  3,268,130
# 11          GA               Georgia                  1,849,944
# 12          HI                Hawaii                    153,375
# 13          ID                 Idaho                    246,708
# ...

# %%
clean_pr_16
# Out:
#    Postal Code                Region Poverty Estimate, All Ages  \
# 0           US         United States                 44,268,996
# 1           AL               Alabama                    814,197
# 2           AK                Alaska                     71,916
# 3           AZ               Arizona                  1,107,153
# 4           AR              Arkansas                    497,388
# 5           CA            California                  5,527,621
# 6           CO              Colorado                    598,378
# 7           CT           Connecticut                    342,171
# 8           DE              Delaware                    109,592
# 9           DC  District of Columbia                    119,778
# 10          FL               Florida                  2,986,237
# 11          GA               Georgia                  1,612,368
# 12          HI                Hawaii                    132,597
# 13          ID                 Idaho                    228,037
# ...

# %%
clean_pr_19
# Out:
#    Postal Code                Region Poverty Estimate, All Ages  \
# 0           US         United States                 39,490,096
# 1           AL               Alabama                    747,478
# 2           AK                Alaska                     73,033
# 3           AZ               Arizona                    963,007
# 4           AR              Arkansas                    468,575
# 5           CA            California                  4,560,419
# 6           CO              Colorado                    531,331
# 7           CT           Connecticut                    343,101
# 8           DE              Delaware                    106,227
# 9           DC  District of Columbia                     94,985
# 10          FL               Florida                  2,681,832
# 11          GA               Georgia                  1,397,607
# 12          HI                Hawaii                    124,650
# 13          ID                 Idaho                    193,741
# ...

# %%
clean_pr_13['Median Household Income'] = clean_pr_13['Median Household Income'].str.replace(',', '')
clean_pr_16['Median Household Income'] = clean_pr_16['Median Household Income'].str.replace(',', '')
clean_pr_19['Median Household Income'] = clean_pr_19['Median Household Income'].str.replace(',', '')

# %%
clean_pr_13['Median Household Income'] = clean_pr_13['Median Household Income'].astype(str).astype(int)                                                                                                  
clean_pr_16['Median Household Income'] = clean_pr_16['Median Household Income'].astype(str).astype(int)
clean_pr_19['Median Household Income'] = clean_pr_19['Median Household Income'].astype(str).astype(int)

# %%
top_ten_income_19 = clean_pr_19.sort_values(['Median Household Income'], ascending = False).head()
top_ten_income_19
# Out:
#    Postal Code                Region Poverty Estimate, All Ages  \
# 9           DC  District of Columbia                     94,985
# 21          MD              Maryland                    537,717
# 31          NJ            New Jersey                    795,676
# 22          MA         Massachusetts                    631,551
# 12          HI                Hawaii                    124,650
#
#    90% CI Lower Bound 90% CI Upper Bound  Poverty Percent, All Ages  \
# 9              88,692            101,278                       14.1
# 21            523,164            552,270                        9.1
# 31            775,971            815,381                        9.1
# 22            615,762            647,340                        9.5
# 12            118,029            131,271                        9.0
#
#     90% CI Lower Bound.1  90% CI Upper Bound.1  Median Household Income  \
# 9                   13.2                  15.0                    90395
# ...

# %%
top_ten_income_13 = clean_pr_13.sort_values(['Median Household Income'], ascending = False).head()
top_ten_income_13
# Out:
#    Postal Code       Region Poverty Estimate, All Ages 90% CI Lower Bound  \
# 21          MD     Maryland                    591,457            576,662
# 31          NJ   New Jersey                    995,390            975,579
# 2           AK       Alaska                     72,643             69,056
# 12          HI       Hawaii                    153,375            146,661
# 7           CT  Connecticut                    373,387            362,267
#
#    90% CI Upper Bound  Poverty Percent, All Ages  90% CI Lower Bound.1  \
# 21            606,252                       10.2                   9.9
# 31          1,015,201                       11.4                  11.2
# 2              76,230                       10.1                   9.6
# 12            160,089                       11.2                  10.7
# 7             384,507                       10.7                  10.4
#
#     90% CI Upper Bound.1  Median Household Income 90% CI Lower Bound.6  \
# ...

# %%
top_ten_income_16 = clean_pr_16.sort_values(['Median Household Income'], ascending = False).head()
top_ten_income_16
# Out:
#    Postal Code         Region Poverty Estimate, All Ages 90% CI Lower Bound  \
# 21          MD       Maryland                    572,786            559,536
# 31          NJ     New Jersey                    915,390            895,106
# 2           AK         Alaska                     71,916             67,813
# 22          MA  Massachusetts                    688,366            672,883
# 12          HI         Hawaii                    132,597            125,573
#
#    90% CI Upper Bound  Poverty Percent, All Ages  90% CI Lower Bound.1  \
# 21            586,036                        9.7                   9.5
# 31            935,674                       10.4                  10.2
# 2              76,019                        9.9                   9.3
# 22            703,849                       10.5                  10.3
# 12            139,621                        9.5                   9.0
#
#     90% CI Upper Bound.1  Median Household Income 90% CI Lower Bound.6  \
# ...

# %%
bottom_ten_income_13 = clean_pr_13.sort_values(['Median Household Income'], ascending = True).head()
bottom_ten_income_13
# Out:
#    Postal Code         Region Poverty Estimate, All Ages 90% CI Lower Bound  \
# 25          MS    Mississippi                    692,058            677,339
# 4           AR       Arkansas                    557,399            545,273
# 49          WV  West Virginia                    331,674            322,877
# 1           AL        Alabama                    889,091            873,141
# 18          KY       Kentucky                    803,044            788,501
#
#    90% CI Upper Bound  Poverty Percent, All Ages  90% CI Lower Bound.1  \
# 25            706,777                       23.9                  23.4
# 4             569,525                       19.4                  19.0
# 49            340,471                       18.4                  17.9
# 1             905,041                       18.9                  18.6
# 18            817,587                       18.8                  18.5
#
#     90% CI Upper Bound.1  Median Household Income 90% CI Lower Bound.6  \
# ...

# %%
bottom_ten_income_16 = clean_pr_16.sort_values(['Median Household Income'], ascending = True).head()
bottom_ten_income_16
# Out:
#    Postal Code         Region Poverty Estimate, All Ages 90% CI Lower Bound  \
# 25          MS    Mississippi                    606,873            592,527
# 49          WV  West Virginia                    318,368            309,231
# 4           AR       Arkansas                    497,388            485,180
# 19          LA      Louisiana                    911,970            893,612
# 1           AL        Alabama                    814,197            796,927
#
#    90% CI Upper Bound  Poverty Percent, All Ages  90% CI Lower Bound.1  \
# 25            621,219                       21.0                  20.5
# 49            327,505                       17.9                  17.4
# 4             509,596                       17.2                  16.8
# 19            930,328                       20.1                  19.7
# 1             831,467                       17.2                  16.8
#
#     90% CI Upper Bound.1  Median Household Income 90% CI Lower Bound.6  \
# ...

# %%
bottom_ten_income_19 = clean_pr_19.sort_values(['Median Household Income'], ascending = True).head()
bottom_ten_income_19
# Out:
#    Postal Code         Region Poverty Estimate, All Ages 90% CI Lower Bound  \
# 25          MS    Mississippi                    559,764            544,709
# 49          WV  West Virginia                    281,175            271,926
# 4           AR       Arkansas                    468,575            456,478
# 19          LA      Louisiana                    847,739            829,070
# 1           AL        Alabama                    747,478            730,491
#
#    90% CI Upper Bound  Poverty Percent, All Ages  90% CI Lower Bound.1  \
# 25            574,819                       19.5                  19.0
# 49            290,424                       16.2                  15.7
# 4             480,672                       16.0                  15.6
# 19            866,408                       18.8                  18.4
# 1             764,465                       15.6                  15.2
#
#     90% CI Upper Bound.1  Median Household Income 90% CI Lower Bound.6  \
# ...

# %%
data = top_ten_income_13.sort_values('Median Household Income', ascending = True)
plt.figure(figsize = (10,5))
plt.bar('Region', 'Median Household Income', data = top_ten_income_13, color = '#15B5B0')
plt.xticks(rotation = 70)
plt.title('Median Household Income 2013');

# %%
data = bottom_ten_income_13.sort_values('Median Household Income', ascending = True)
plt.figure(figsize = (10,5))
plt.bar('Region', 'Median Household Income', data = bottom_ten_income_13, color = '#cbe1e2')
plt.xticks(rotation = 0)
plt.title('Median Household Income 2013')
plt.annotate(text = '$38,191', xy = (-.25,34000))
plt.annotate(text = '$40,605', xy = (.8,36000))
plt.annotate(text = '$41,195', xy = (1.8,37000))
plt.annotate(text = '$42,882', xy = (2.8,38000))
plt.annotate(text = '$43,307', xy = (3.8,39000));

# %%
data = top_ten_income_16.sort_values('Median Household Income', ascending = True)
plt.figure(figsize = (10,5))
plt.bar('Region', 'Median Household Income', data = top_ten_income_16, color = '#cbe1e2')
plt.xticks(rotation = 70)
plt.title('Median Household Income 2016')
plt.hlines(y=57617,xmin = -1, xmax = 5, color = 'black')
plt.xlim(-.5, 4.5)
plt.annotate(text = 'U.S. Average', xy = (1.75, 50000))
plt.annotate(text = '$78,787', xy = (-.25,65000))
plt.annotate(text = '$76,212', xy = (.80,65000))
plt.annotate(text = '$76,144', xy = (1.8,65000))
plt.annotate(text = '$75,207', xy = (2.8,65000))
plt.annotate(text = '$74,659', xy = (3.8,65000))
# Out:
# Text(3.8, 65000, '$74,659')

# %%
data = bottom_ten_income_16.sort_values('Median Household Income', ascending = True)
plt.figure(figsize = (10,5))
plt.bar('Region', 'Median Household Income', data = bottom_ten_income_16, color = '#cbe1e2')
plt.xticks(rotation = 0)
plt.title('Median Household Income 2016')
#plt.hlines(y=57617,xmin = -1, xmax = 5, color = 'black')
#plt.xlim(-.5, 4.5)
#plt.annotate(text = 'U.S. Average', xy = (1.75, 54000))
plt.annotate(text = '$41,793', xy = (-.25,35000))
plt.annotate(text = '$43,175', xy = (.80,35000))
plt.annotate(text = '$44,406', xy = (1.8,35000))
plt.annotate(text = '$45,374', xy = (2.8,35000))
plt.annotate(text = '$46,309', xy = (3.8,35000))
# Out:
# Text(3.8, 35000, '$46,309')

# %%
data = top_ten_income_19.sort_values('Median Household Income', ascending = True)
plt.figure(figsize = (10,5))
plt.bar('Region', 'Median Household Income', data = top_ten_income_19, color = '#cbe1e2')
plt.xticks(rotation = 70)
plt.title('Median Household Income 2019');

# %%
data = bottom_ten_income_19.sort_values('Median Household Income', ascending = True)
plt.figure(figsize = (10,5))
plt.bar('Region', 'Median Household Income', data = bottom_ten_income_19, color = '#cbe1e2')
plt.xticks(rotation = 0)
plt.title('Median Household Income 2019');
plt.annotate(text = '$45,928', xy = (-.25,41000))
plt.annotate(text = '$48,659', xy = (.80,43000))
plt.annotate(text = '$49020', xy = (1.8,44000))
plt.annotate(text = '$51,108', xy = (2.8,45000))
plt.annotate(text = '$51,771', xy = (3.8,46000))
# Out:
# Text(3.8, 46000, '$51,771')

# %%
plt.figure(figsize=(10, 8))
  
# Defining the values for x-axis, y-axis
# and from which datafarme the values are to be picked
plots = sns.barplot(x="Region", y="Median Household Income", data=top_ten_income_19, color = '#cbe1e2')
  
# Iterrating over the bars one-by-one
for bar in plots.patches:
    
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    plt.title('Median Household Income 2019')
    plots.annotate(format(bar.get_height(), '.2f'), 
                   (bar.get_x() + bar.get_width() / 2, 
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')

# %%
top_ten_poverty_13 = clean_pr_13.sort_values(['Poverty Percent, All Ages'], ascending = False).head()
top_ten_poverty_13
# Out:
#    Postal Code       Region Poverty Estimate, All Ages 90% CI Lower Bound  \
# 25          MS  Mississippi                    692,058            677,339
# 32          NM   New Mexico                    437,923            427,727
# 19          LA    Louisiana                    897,284            879,370
# 4           AR     Arkansas                    557,399            545,273
# 11          GA      Georgia                  1,849,944          1,823,426
#
#    90% CI Upper Bound  Poverty Percent, All Ages  90% CI Lower Bound.1  \
# 25            706,777                       23.9                  23.4
# 32            448,119                       21.4                  20.9
# 19            915,198                       20.0                  19.6
# 4             569,525                       19.4                  19.0
# 11          1,876,462                       19.0                  18.7
#
#     90% CI Upper Bound.1  Median Household Income 90% CI Lower Bound.6  \
# ...

# %%
top_ten_poverty_16 = clean_pr_16.sort_values(['Poverty Percent, All Ages'], ascending = False).head()
top_ten_poverty_16
# Out:
#    Postal Code                Region Poverty Estimate, All Ages  \
# 25          MS           Mississippi                    606,873
# 19          LA             Louisiana                    911,970
# 32          NM            New Mexico                    390,461
# 9           DC  District of Columbia                    119,778
# 18          KY              Kentucky                    782,779
#
#    90% CI Lower Bound 90% CI Upper Bound  Poverty Percent, All Ages  \
# 25            592,527            621,219                       21.0
# 19            893,612            930,328                       20.1
# 32            380,077            400,845                       19.1
# 9             113,591            125,965                       18.5
# 18            766,290            799,268                       18.2
#
#     90% CI Lower Bound.1  90% CI Upper Bound.1  Median Household Income  \
# 25                  20.5                  21.5                    41793
# ...

# %%
top_ten_poverty_19 = clean_pr_19.sort_values(['Poverty Percent, All Ages'], ascending = False).head()
top_ten_poverty_19
# Out:
#    Postal Code         Region Poverty Estimate, All Ages 90% CI Lower Bound  \
# 25          MS    Mississippi                    559,764            544,709
# 19          LA      Louisiana                    847,739            829,070
# 32          NM     New Mexico                    358,526            348,384
# 49          WV  West Virginia                    281,175            271,926
# 4           AR       Arkansas                    468,575            456,478
#
#    90% CI Upper Bound  Poverty Percent, All Ages  90% CI Lower Bound.1  \
# 25            574,819                       19.5                  19.0
# 19            866,408                       18.8                  18.4
# 32            368,668                       17.5                  17.0
# 49            290,424                       16.2                  15.7
# 4             480,672                       16.0                  15.6
#
#     90% CI Upper Bound.1  Median Household Income 90% CI Lower Bound.6  \
# ...

# %%
data = top_ten_poverty_19.sort_values('Poverty Percent, All Ages', ascending = True)
plt.figure(figsize = (10,5))
plt.bar('Region', 'Poverty Percent, All Ages', data = top_ten_poverty_19, color = '#15B5B0')
plt.xticks(rotation = 0)
plt.title('Top 5 states poverty rates 2019')
;
plt.annotate(text = '19.5%', xy = (-.15,17))
plt.annotate(text = '18.8%', xy = (.85,16.4))
plt.annotate(text = '17.5%', xy = (1.85,15))
plt.annotate(text = '16.2%', xy = (2.87,14))
plt.annotate(text = '16.0%', xy = (3.85,14));

# %%
data = top_ten_poverty_16.sort_values('Poverty Percent, All Ages', ascending = True)
plt.figure(figsize = (10,5))
plt.bar('Region', 'Poverty Percent, All Ages', data = top_ten_poverty_16, color = '#15B5B0')
plt.xticks(rotation = 0)
plt.title('Top 5 states poverty rates 2016');
plt.annotate(text = '21.0%', xy = (-.15,18.5))
plt.annotate(text = '20.1%', xy = (.85,17.5))
plt.annotate(text = '19.1%', xy = (1.85,16.5))
plt.annotate(text = '18.5%', xy = (2.87,16))
plt.annotate(text = '18.2%', xy = (3.85,15));

# %%
data = top_ten_poverty_13.sort_values('Poverty Percent, All Ages', ascending = True)
plt.figure(figsize = (10,5))
plt.bar('Region', 'Poverty Percent, All Ages', data = top_ten_poverty_13, color = '#15B5B0')
plt.xticks(rotation = 0)
plt.title('Top 5 states poverty rates 2013');
plt.annotate(text = '23.9%', xy = (-.15,21.5))
plt.annotate(text = '21.4%', xy = (.85,19))
plt.annotate(text = '20.0%', xy = (1.85,17.5))
plt.annotate(text = '19.4%', xy = (2.87,16.5))
plt.annotate(text = '19.0%', xy = (3.85,16.5));

# %%
decimals = 1
top_ten_poverty_13 = top_ten_poverty_13[['Region', 'Poverty Percent, All Ages']]
top_ten_poverty_13 = table_16.rename(columns = {'Poverty Percent, All Ages':'Poverty Rate'})
top_ten_poverty_13['Poverty Percent, All Ages']= (top_ten_poverty_13['Poverty Percent, All Ages'].apply(lambda x: round(x, decimals))
# Out:
#   File "<ipython-input-57-d689f61ed74b>", line 4
#     top_ten_poverty_13['Poverty Percent, All Ages']= (top_ten_poverty_13['Poverty Percent, All Ages'].apply(lambda x: round(x, decimals))
#                                                                                                                                          ^
# SyntaxError: unexpected EOF while parsing

# %%
top_ten_income_13['Poverty Percent, All Ages'] = top_ten_income_13['Poverty Percent, All Ages'].astype(float,errors = 'raise')
top_ten_income_13.dtypes
top_ten_income_16['Poverty Percent, All Ages'] = top_ten_income_16['Poverty Percent, All Ages'].astype(float,errors = 'raise')
top_ten_income_16.dtypes
top_ten_income_19['Poverty Percent, All Ages'] = top_ten_income_19['Poverty Percent, All Ages'].astype(float,errors = 'raise')
top_ten_income_19.dtypes
# Out:
# Postal Code                    object
# Region                         object
# Poverty Estimate, All Ages     object
# 90% CI Lower Bound             object
# 90% CI Upper Bound             object
# Poverty Percent, All Ages     float64
# 90% CI Lower Bound.1          float64
# 90% CI Upper Bound.1          float64
# Median Household Income         int32
# 90% CI Lower Bound.6           object
# 90% CI Upper Bound.6           object
# Year                            int64
# dtype: object

# %%
top_ten_income_13['Poverty Percent, All Ages'] = pd.to_numeric(top_ten_income_13['Poverty Percent, All Ages'],errors = 'coerce')
top_ten_income_13.dtypes
# Out:
# Postal Code                    object
# Region                         object
# Poverty Estimate, All Ages     object
# 90% CI Lower Bound             object
# 90% CI Upper Bound             object
# Poverty Percent, All Ages     float64
# 90% CI Lower Bound.1          float64
# 90% CI Upper Bound.1          float64
# Median Household Income         int32
# 90% CI Lower Bound.6           object
# 90% CI Upper Bound.6           object
# Year                            int64
# dtype: object

# %%
decimals = 1    
top_ten_poverty_13['Poverty Percent, All Ages'] = top_ten_poverty_13['Poverty Percent, All Ages'].apply(lambda x: round(x, decimals))
# Out:
# <ipython-input-58-99f98859587d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_ten_poverty_13['Poverty Percent, All Ages'] = top_ten_poverty_13['Poverty Percent, All Ages'].apply(lambda x: round(x, decimals))

# %%
top
