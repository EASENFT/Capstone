# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
obesity_df = pd.read_csv('../data/Behavioral_Risk_Factor_Surveillance_System__BRFSS__Prevalence_Data__2011_to_present_.csv')

# %%
obesity_df.head()
# Out:
#    Year Locationabbr Locationdesc          Class           Topic  \
# 0  2012           GU         Guam   Demographics             Age
# 1  2012           GU         Guam   Demographics             Age
# 2  2013           GU         Guam  Health Status  Overall Health
# 3  2013           GU         Guam   Demographics  Marital Status
# 4  2013           PR  Puerto Rico   Demographics             Age
#
#                        Question     Response       Break_Out  \
# 0             What is your age?  55-64 years         Overall
# 1             What is your age?  35-44 years          Female
# 2   How is your general health?    Excellent           18-24
# 3  What is your marital status?    Partnered  H.S. or G.E.D.
# 4             What is your age?  25-34 years  Some post-H.S.
#
#    Break_Out_Category  Sample_Size  ...  Data_Value_Footnote  DataSource  \
# 0             Overall          296  ...                  NaN       BRFSS
# ...

# %%
is_overweight = obesity_df['Class'] == 'Overweight and Obesity (BMI)'
is_overweight
#filtering down to rows that deal with obesity
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1827487    False
# 1827488    False
# 1827489    False
# 1827490    False
# 1827491    False
# Name: Class, Length: 1827492, dtype: bool

# %%
obesity_df_2019 = obesity_df[is_overweight]
obesity_df_2019
# Out:
#          Year Locationabbr Locationdesc                         Class  \
# 46       2019           KY     Kentucky  Overweight and Obesity (BMI)
# 125      2019           AK       Alaska  Overweight and Obesity (BMI)
# 126      2019           AK       Alaska  Overweight and Obesity (BMI)
# 533      2019           ID        Idaho  Overweight and Obesity (BMI)
# 534      2019           ID        Idaho  Overweight and Obesity (BMI)
# ...       ...          ...          ...                           ...
# 1827236  2018           PR  Puerto Rico  Overweight and Obesity (BMI)
# 1827253  2018           GU         Guam  Overweight and Obesity (BMI)
# 1827258  2018           WI    Wisconsin  Overweight and Obesity (BMI)
# 1827307  2018           WI    Wisconsin  Overweight and Obesity (BMI)
# 1827409  2018           WI    Wisconsin  Overweight and Obesity (BMI)
#
#                   Topic                                           Question  \
# ...

# %%
obesity_df_2019.shape
# Out:
# (47074, 27)
