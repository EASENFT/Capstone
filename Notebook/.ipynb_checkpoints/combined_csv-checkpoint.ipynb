# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
obesity_df = pd.read_csv('../cleaned_python_csv/obesity_overall.csv')
obesity_df.head()
# Out:
#    Unnamed: 0  Year Locationabbr   Region                         Class  \
# 0          14  2019           AK   Alaska  Overweight and Obesity (BMI)
# 1          38  2019           AK   Alaska  Overweight and Obesity (BMI)
# 2          51  2019           AK   Alaska  Overweight and Obesity (BMI)
# 3          74  2019           AK   Alaska  Overweight and Obesity (BMI)
# 4         108  2019           AL  Alabama  Overweight and Obesity (BMI)
#
#             Topic                                           Question  \
# 0  BMI Categories  Weight classification by Body Mass Index (BMI)...
# 1  BMI Categories  Weight classification by Body Mass Index (BMI)...
# 2  BMI Categories  Weight classification by Body Mass Index (BMI)...
# 3  BMI Categories  Weight classification by Body Mass Index (BMI)...
# 4  BMI Categories  Weight classification by Body Mass Index (BMI)...
#
#                         Response Break_Out Break_Out_Category  ...  \
# ...

# %%
pr_df_13 = pd.read_csv('../cleaned_python_csv/clean_pr_13.csv')
pr_df_16 = pd.read_csv('../cleaned_python_csv/clean_pr_16.csv')
pr_df_19 = pd.read_csv('../cleaned_python_csv/clean_pr_19.csv')

# %%
pr_df_13.head()
# Out:
#    Unnamed: 0 Postal Code         Region Poverty Estimate, All Ages  \
# 0           0          US  United States                 48,810,868
# 1           1          AL        Alabama                    889,091
# 2           2          AK         Alaska                     72,643
# 3           3          AZ        Arizona                  1,206,948
# 4           4          AR       Arkansas                    557,399
#
#   90% CI Lower Bound 90% CI Upper Bound  Poverty Percent, All Ages  \
# 0         48,554,692         49,067,044                       15.8
# 1            873,141            905,041                       18.9
# 2             69,056             76,230                       10.1
# 3          1,184,107          1,229,789                       18.6
# 4            545,273            569,525                       19.4
#
#    90% CI Lower Bound.1  90% CI Upper Bound.1 Median Household Income  \
# 0                  15.7                  15.9                  52,250
# ...

# %%
pr_df_16
# Out:
#     Unnamed: 0 Postal Code                Region Poverty Estimate, All Ages  \
# 0            0          US         United States                 44,268,996
# 1            1          AL               Alabama                    814,197
# 2            2          AK                Alaska                     71,916
# 3            3          AZ               Arizona                  1,107,153
# 4            4          AR              Arkansas                    497,388
# 5            5          CA            California                  5,527,621
# 6            6          CO              Colorado                    598,378
# 7            7          CT           Connecticut                    342,171
# 8            8          DE              Delaware                    109,592
# 9            9          DC  District of Columbia                    119,778
# 10          10          FL               Florida                  2,986,237
# ...

# %%
income_df_13_below = pr_df_13[pr_df_13['Median Household Income']<= '53,250']
income_df_13_below.shape
pr_df_13_below = pr_df_13[pr_df_13['Poverty Percent, All Ages']>= 14.0]
pr_df_13_below
# Out:
#     Unnamed: 0 Postal Code                Region Poverty Estimate, All Ages  \
# 0            0          US         United States                 48,810,868
# 1            1          AL               Alabama                    889,091
# 3            3          AZ               Arizona                  1,206,948
# 4            4          AR              Arkansas                    557,399
# 5            5          CA            California                  6,328,064
# 9            9          DC  District of Columbia                    115,096
# 10          10          FL               Florida                  3,268,130
# 11          11          GA               Georgia                  1,849,944
# 13          13          ID                 Idaho                    246,708
# 14          14          IL              Illinois                  1,841,996
# 15          15          IN               Indiana                  1,008,411
# ...
